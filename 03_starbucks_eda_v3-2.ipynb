# %% [markdown]
# # 스타벅스 입지 분석

# %% [markdown]
# ## Phase1. EDA
# ### 1.1 데이터 확인

# %%
import os
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import koreanize_matplotlib
import seaborn as sns

import geopandas as gpd # shp 파일 로드
import contextily as ctx # 서울시 지도 불러올 때

import folium
import folium.plugins as plugins

# %%
cd Desktop/prj/상권분석/git/market_area_analysis/
# Out:
# [Errno 2] No such file or directory: 'Desktop/prj/상권분석/git/market_area_analysis/'
# /Users/jade/Desktop/prj/market_analysis/git/market_area_analysis

# %%
df = pd.read_csv('../processed/analysis_df.csv')

df.head(1)
# Out:
#         상호명 상권업종대분류명 상권업종중분류명 상권업종소분류명 시군구명       행정동코드 행정동명  \
# 0  부동산임대김은숙       음식    비알코올        카페  종로구  1111054000  삼청동
#
#                   지번주소                도로명주소         경도  ...  7세19세  20세25세  \
# 0  서울특별시 종로구 삼청동 28-21  서울특별시 종로구 삼청로 122-1  126.98184  ...    189     108
#
#    26세30세  31세40세  41세50세 51세60세  61세109세  평당거래금액(만원)  상권중심점  상권중심점거리
# 0     143     275     298    333      770       583.0     17     2.03
#
# [1 rows x 35 columns]

# %%
df.to_csv('../processed/analysis_df.csv', index=False, encoding='utf-8-sig')

# %%
df_starbucks = df[df['스타벅스']==1]

df_starbucks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 641 entries, 518203 to 518843
# Data columns (total 35 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   상호명         641 non-null    object
#  1   상권업종대분류명    641 non-null    object
#  2   상권업종중분류명    641 non-null    object
#  3   상권업종소분류명    641 non-null    object
#  4   시군구명        641 non-null    object
#  5   행정동코드       641 non-null    int64
#  6   행정동명        641 non-null    object
#  7   지번주소        641 non-null    object
#  8   도로명주소       641 non-null    object
#  9   경도          641 non-null    float64
#  10  위도          641 non-null    float64
#  11  스타벅스        641 non-null    int64
#  12  근방가게수       641 non-null    int64
#  13  근방음식점수      641 non-null    int64
#  14  근방카페수       641 non-null    int64
#  15  근방지하철역      641 non-null    object
#  16  근방지하철역거리    641 non-null    float64
#  17  승차이용객수      641 non-null    float64
#  18  승차출근시간대     641 non-null    float64
#  19  승차퇴근시간대     641 non-null    float64
#  20  하차이용객수      641 non-null    float64
#  21  하차출근시간대     641 non-null    float64
#  22  하차퇴근시간대     641 non-null    float64
#  23  계           641 non-null    int64
#  24  0세6세        641 non-null    int64
#  25  7세19세       641 non-null    int64
#  26  20세25세      641 non-null    int64
#  27  26세30세      641 non-null    int64
#  28  31세40세      641 non-null    int64
#  29  41세50세      641 non-null    int64
#  30  51세60세      641 non-null    int64
#  31  61세109세     641 non-null    int64
#  32  평당거래금액(만원)  641 non-null    float64
#  33  상권중심점       641 non-null    int64
#  34  상권중심점거리     641 non-null    float64
# dtypes: float64(11), int64(15), object(9)
# memory usage: 180.3+ KB

# %%
df_cafe = df[df['상권업종소분류명']=='카페']

# %%
print(f"스타벅스 매장 수: {df_cafe['스타벅스'].sum()}")
print(f"비 스타벅스 카페 수: {df_cafe[df_cafe['스타벅스']==0]['스타벅스'].count()}")
# Out:
# 스타벅스 매장 수: 641
# 비 스타벅스 카페 수: 21983

# %% [markdown]
# ## Phase2: 지리적 분석

# %% [markdown]
# ### 2.1 지역별 분포 분석

# %%
df_district_gu = df_starbucks['시군구명'].value_counts().reset_index()
df_district_gu.columns = ['시군구명', '스타벅스_count']
df_district_gu['스타벅스_ratio'] = df_district_gu['스타벅스_count'] / df_district_gu['스타벅스_count'].sum()
df_district_gu['스타벅스_ratio'] = round(df_district_gu['스타벅스_ratio'] *100, 2)
df_district_gu.sort_values(by='스타벅스_ratio', ascending=False, inplace=True)
df_district_gu.reset_index(drop=True, inplace=True)
df_district_gu
# Out:
#     시군구명  스타벅스_count  스타벅스_ratio
# 0    강남구          95       14.82
# 1     중구          51        7.96
# 2    서초구          51        7.96
# 3   영등포구          42        6.55
# 4    종로구          42        6.55
# 5    마포구          37        5.77
# 6    송파구          37        5.77
# 7    강서구          32        4.99
# 8    용산구          25        3.90
# 9   서대문구          23        3.59
# 10   강동구          19        2.96
# 11   광진구          19        2.96
# 12   성북구          17        2.65
# 13   은평구          16        2.50
# 14   양천구          16        2.50
# 15   성동구          15        2.34
# 16   노원구          15        2.34
# 17   금천구          14        2.18
# 18  동대문구          14        2.18
# 19   관악구          13        2.03
# 20   동작구          13        2.03
# 21   구로구          12        1.87
# 22   중랑구           9        1.40
# 23   도봉구           7        1.09
# 24   강북구           7        1.09

# %%
sns.barplot(data=df_district_gu, x='시군구명', y='스타벅스_count', color='green')
plt.xticks(rotation=90)
plt.hlines(y=df_district_gu['스타벅스_count'].mean(), xmin=0, xmax=len(df_district_gu), color='red', linestyle='--')
plt.text(x=21, y=df_district_gu['스타벅스_count'].mean()+3, s=f'평균: {df_district_gu["스타벅스_count"].mean():.2f}', ha='left', va='bottom')
plt.xlabel('시군구명')
plt.ylabel('스타벅스 매장 수')
plt.title('시군구별 스타벅스 매장 수')
plt.tight_layout()
plt.show()

# %%
df_district_dong = df_starbucks['행정동명'].value_counts().reset_index()
df_district_dong.columns = ['행정동명', '스타벅스_count']
df_district_dong['스타벅스_ratio'] = df_district_dong.iloc[:,1]/641
df_district_dong['스타벅스_ratio'] = round(df_district_dong['스타벅스_ratio'] *100, 2)
df_district_dong.sort_values(by='스타벅스_ratio', ascending=False, inplace=True)
df_district_dong
# Out:
#             행정동명  스타벅스_count  스타벅스_ratio
# 0           역삼1동          22        3.43
# 1            여의동          22        3.43
# 2    종로1.2.3.4가동          18        2.81
# 3             명동          15        2.34
# 4            신촌동          12        1.87
# ..           ...         ...         ...
# 246       원효로제1동           1        0.16
# 247        면목제7동           1        0.16
# 248        상봉제1동           1        0.16
# 249         묵제1동           1        0.16
# 250        중화제2동           1        0.16
#
# [251 rows x 3 columns]

# %% [markdown]
# ### 2.2 공간적 특성 분석
# - 시군구, 행정동별
#     - 상권 중심점까지의 거리
#     - 근방 지하철역까지의 거리
#     - 평당 거래 금액(만원)

# %%
# df_starbucks.columns
df_starbucks[['상권중심점거리','근방지하철역거리','평당거래금액(만원)']].describe()[1:]
# Out:
#        상권중심점거리  근방지하철역거리   평당거래금액(만원)
# mean  1.602574  0.458768   348.077379
# std   0.822579  0.504546   334.420143
# min   0.070000  0.020000     0.300000
# 25%   1.020000  0.150000   148.700000
# 50%   1.530000  0.300000   256.300000
# 75%   2.030000  0.580000   448.200000
# max   5.750000  4.500000  2721.500000

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 3))

sns.histplot(df_starbucks['상권중심점거리'], ax=axes[0], color='green')
axes[0].set_title('상권중심점거리')
axes[0].axvline(df_starbucks['상권중심점거리'].mean(), color='red', linestyle='--')
axes[0].text(x=df_starbucks['상권중심점거리'].mean()+0.5, y=80, s=f'평균: {df_starbucks["상권중심점거리"].mean():.2f}', ha='left', va='bottom', color='red')
axes[0].axvline(df_starbucks['상권중심점거리'].median(), color='blue', linestyle='--')
axes[0].text(x=df_starbucks['상권중심점거리'].median()-0.5, y=80, s=f'중앙값: {df_starbucks["상권중심점거리"].median():.2f}', ha='right', va='bottom', color='blue')

sns.histplot(df_starbucks['근방지하철역거리'], ax=axes[1], color='green')
axes[1].set_title('근방지하철역거리')
axes[1].axvline(df_starbucks['근방지하철역거리'].mean(), color='red', linestyle='--')
axes[1].text(x=df_starbucks['근방지하철역거리'].mean(), y=100, s=f'평균: {df_starbucks["근방지하철역거리"].mean():.2f}', ha='left', va='top', color='red')
axes[1].axvline(df_starbucks['근방지하철역거리'].median(), color='blue', linestyle='--')
axes[1].text(x=df_starbucks['근방지하철역거리'].median()+0.2, y=100, s=f'중앙값: {df_starbucks["근방지하철역거리"].median():.2f}', ha='left', va='bottom', color='blue')

sns.histplot(df_starbucks['평당거래금액(만원)'], ax=axes[2], color='green')
axes[2].set_title('평당거래금액(만원)')
axes[2].axvline(df_starbucks['평당거래금액(만원)'].mean(), color='red', linestyle='--')
axes[2].text(x=df_starbucks['평당거래금액(만원)'].mean()+120, y=60, s=f'평균: {df_starbucks["평당거래금액(만원)"].mean():.2f}', ha='left', va='top', color='red')
axes[2].axvline(df_starbucks['평당거래금액(만원)'].median(), color='blue', linestyle='--')
axes[2].text(x=df_starbucks['평당거래금액(만원)'].median()+200, y=60, s=f'중앙값: {df_starbucks["평당거래금액(만원)"].median():.2f}', ha='left', va='bottom', color='blue')


plt.tight_layout()
plt.show()

# %%
df_starbucks.groupby('시군구명')[['상권중심점거리','근방지하철역거리','평당거래금액(만원)']].mean().style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_9d825_row0_col0 {
#   background-color: #d2edcc;
#   color: #000000;
# }
# #T_9d825_row0_col1 {
#   background-color: #ceecc8;
#   color: #000000;
# }
# #T_9d825_row0_col2, #T_9d825_row7_col1, #T_9d825_row16_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_9d825_row1_col0 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_9d825_row1_col1, #T_9d825_row11_col1 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_9d825_row1_col2 {
#   background-color: #84cc83;
#   color: #000000;
# }
# #T_9d825_row2_col0 {
#   background-color: #9cd797;
#   color: #000000;
# }
# #T_9d825_row2_col1 {
#   background-color: #65bd6f;
#   color: #f1f1f1;
# }
# #T_9d825_row2_col2, #T_9d825_row15_col1, #T_9d825_row23_col0 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_9d825_row3_col0, #T_9d825_row12_col0 {
#   background-color: #afdfa8;
#   color: #000000;
# }
# #T_9d825_row3_col1 {
#   background-color: #0b7734;
#   color: #f1f1f1;
# }
# #T_9d825_row3_col2, #T_9d825_row7_col2 {
#   background-color: #c4e8bd;
#   color: #000000;
# }
# #T_9d825_row4_col0, #T_9d825_row4_col2 {
#   background-color: #ccebc6;
#   color: #000000;
# }
# #T_9d825_row4_col1 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_9d825_row5_col0, #T_9d825_row19_col1 {
#   background-color: #c1e6ba;
#   color: #000000;
# }
# #T_9d825_row5_col1 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_9d825_row5_col2 {
#   background-color: #91d28e;
#   color: #000000;
# }
# #T_9d825_row6_col0 {
#   background-color: #43ac5e;
#   color: #f1f1f1;
# }
# #T_9d825_row6_col1, #T_9d825_row11_col0 {
#   background-color: #1a843f;
#   color: #f1f1f1;
# }
# #T_9d825_row6_col2, #T_9d825_row9_col2 {
#   background-color: #c8e9c1;
#   color: #000000;
# }
# #T_9d825_row7_col0 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_9d825_row8_col0 {
#   background-color: #38a156;
#   color: #f1f1f1;
# }
# #T_9d825_row8_col1 {
#   background-color: #9bd696;
#   color: #000000;
# }
# #T_9d825_row8_col2 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_9d825_row9_col0, #T_9d825_row13_col1 {
#   background-color: #a2d99c;
#   color: #000000;
# }
# #T_9d825_row9_col1 {
#   background-color: #7dc87e;
#   color: #000000;
# }
# #T_9d825_row10_col0 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
# }
# #T_9d825_row10_col1 {
#   background-color: #1f8742;
#   color: #f1f1f1;
# }
# #T_9d825_row10_col2 {
#   background-color: #b2e0ac;
#   color: #000000;
# }
# #T_9d825_row11_col2 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_9d825_row12_col1 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_9d825_row12_col2 {
#   background-color: #94d390;
#   color: #000000;
# }
# #T_9d825_row13_col0, #T_9d825_row23_col2 {
#   background-color: #2b934b;
#   color: #f1f1f1;
# }
# #T_9d825_row13_col2 {
#   background-color: #c2e7bb;
#   color: #000000;
# }
# #T_9d825_row14_col0 {
#   background-color: #a3da9d;
#   color: #000000;
# }
# #T_9d825_row14_col1 {
#   background-color: #c0e6b9;
#   color: #000000;
# }
# #T_9d825_row14_col2 {
#   background-color: #3ea75a;
#   color: #f1f1f1;
# }
# #T_9d825_row15_col0 {
#   background-color: #39a257;
#   color: #f1f1f1;
# }
# #T_9d825_row15_col2 {
#   background-color: #98d594;
#   color: #000000;
# }
# #T_9d825_row16_col1 {
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_9d825_row16_col2 {
#   background-color: #a4da9e;
#   color: #000000;
# }
# #T_9d825_row17_col0 {
#   background-color: #157f3b;
#   color: #f1f1f1;
# }
# #T_9d825_row17_col1 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_9d825_row17_col2 {
#   background-color: #6dc072;
#   color: #000000;
# }
# #T_9d825_row18_col0 {
#   background-color: #268e47;
#   color: #f1f1f1;
# }
# #T_9d825_row18_col1 {
#   background-color: #258d47;
#   color: #f1f1f1;
# }
# #T_9d825_row18_col2 {
#   background-color: #bae3b3;
#   color: #000000;
# }
# #T_9d825_row19_col0 {
#   background-color: #bee5b8;
#   color: #000000;
# }
# #T_9d825_row19_col2 {
#   background-color: #46ae60;
#   color: #f1f1f1;
# }
# #T_9d825_row20_col0 {
#   background-color: #37a055;
#   color: #f1f1f1;
# }
# #T_9d825_row20_col1 {
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_9d825_row20_col2 {
#   background-color: #278f48;
#   color: #f1f1f1;
# }
# #T_9d825_row21_col0 {
#   background-color: #067230;
#   color: #f1f1f1;
# }
# #T_9d825_row21_col1 {
#   background-color: #9ed798;
#   color: #000000;
# }
# #T_9d825_row21_col2 {
#   background-color: #92d28f;
#   color: #000000;
# }
# #T_9d825_row22_col0 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_9d825_row22_col1 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_9d825_row22_col2 {
#   background-color: #016e2d;
#   color: #f1f1f1;
# }
# #T_9d825_row23_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_9d825_row24_col0 {
#   background-color: #a9dca3;
#   color: #000000;
# }
# #T_9d825_row24_col1 {
#   background-color: #8ace88;
#   color: #000000;
# }
# #T_9d825_row24_col2 {
#   background-color: #e8f6e4;
#   color: #000000;
# }
# </style>
# <table id="T_9d825">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d825_level0_col0" class="col_heading level0 col0" >상권중심점거리</th>
#       <th id="T_9d825_level0_col1" class="col_heading level0 col1" >근방지하철역거리</th>
#       <th id="T_9d825_level0_col2" class="col_heading level0 col2" >평당거래금액(만원)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >시군구명</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d825_level0_row0" class="row_heading level0 row0" >강남구</th>
#       <td id="T_9d825_row0_col0" class="data row0 col0" >1.410632</td>
#       <td id="T_9d825_row0_col1" class="data row0 col1" >0.407474</td>
#       <td id="T_9d825_row0_col2" class="data row0 col2" >545.375789</td>
#     </tr>
#     <tr>
#       <th id="T_9d825_level0_row1" class="row_heading level0 row1" >강동구</th>
#       <td id="T_9d825_row1_col0" class="data row1 col0" >1.940000</td>
#       <td id="T_9d825_row1_col1" class="data row1 col1" >0.432632</td>
#       <td id="T_9d825_row1_col2" class="data row1 col2" >302.184211</td>
#     </tr>
#     <tr>
#       <th id="T_9d825_level0_row2" class="row_heading level0 row2" >강북구</th>
#       <td id="T_9d825_row2_col0" class="data row2 col0" >1.584286</td>
#       <td id="T_9d825_row2_col1" class="data row2 col1" >0.661429</td>
#       <td id="T_9d825_row2_col2" class="data row2 col2" >100.142857</td>
#     </tr>
#     <tr>
#       <th id="T_9d825_level0_row3" class="row_heading level0 row3" >강서구</th>
#       <td id="T_9d825_row3_col0" class="data row3 col0" >1.527500</td>
#       <td id="T_9d825_row3_col1" class="data row3 col1" >0.899375</td>
#       <td id="T_9d825_row3_col2" class="data row3 col2" >214.993750</td>
#     </tr>
#     <tr>
#       <th id="T_9d825_level0_row4" class="row_heading level0 row4" >관악구</th>
#       <td id="T_9d825_row4_col0" class="data row4 col0" >1.432308</td>
#       <td id="T_9d825_row4_col1" class="data row4 col1" >0.273846</td>
#       <td id="T_9d825_row4_col2" class="data row4 col2" >201.284615</td>
#     </tr>
#     <tr>
#       <th id="T_9d825_level0_row5" class="row_heading level0 row5" >광진구</th>
#       <td id="T_9d825_row5_col0" class="data row5 col0" >1.471579</td>
#       <td id="T_9d825_row5_col1" class="data row5 col1" >0.265789</td>
#       <td id="T_9d825_row5_col2" class="data row5 col2" >287.215789</td>
#     </tr>
#     <tr>
#       <th id="T_9d825_level0_row6" class="row_heading level0 row6" >구로구</th>
#       <td id="T_9d825_row6_col0" class="data row6 col0" >1.799167</td>
#       <td id="T_9d825_row6_col1" class="data row6 col1" >0.855000</td>
#       <td id="T_9d825_row6_col2" class="data row6 col2" >210.041667</td>
#     </tr>
#     <tr>
#       <th id="T_9d825_level0_row7" class="row_heading level0 row7" >금천구</th>
#       <td id="T_9d825_row7_col0" class="data row7 col0" >1.284286</td>
#       <td id="T_9d825_row7_col1" class="data row7 col1" >1.030714</td>
#       <td id="T_9d825_row7_col2" class="data row7 col2" >216.350000</td>
#     </tr>
#     <tr>
#       <th id="T_9d825_level0_row8" class="row_heading level0 row8" >노원구</th>
#       <td id="T_9d825_row8_col0" class="data row8 col0" >1.842667</td>
#       <td id="T_9d825_row8_col1" class="data row8 col1" >0.545333</td>
#       <td id="T_9d825_row8_col2" class="data row8 co

# %%
gu_cnt = df_starbucks['시군구명'].unique()

fig, axes = plt.subplots(1, 3, figsize=(15, 3))

sns.boxplot(data=df_starbucks, x='시군구명', y='상권중심점거리', ax=axes[0], color='green')
axes[0].hlines(y=df_starbucks['상권중심점거리'].mean(), xmin=0, xmax=df_starbucks['시군구명'].nunique(), color='red', linestyle='--')
axes[0].set_xticks(gu_cnt)
axes[0].set_xticklabels(gu_cnt, rotation=90)
axes[0].text(x=0.5, y=df_starbucks['상권중심점거리'].mean()+1, s=f'평균: {df_starbucks["상권중심점거리"].mean():.2f}', ha='left', va='bottom', color='red')


sns.boxplot(data=df_starbucks, x='시군구명', y='근방지하철역거리', ax=axes[1], color='green')
axes[1].hlines(y=df_starbucks['근방지하철역거리'].mean(), xmin=0, xmax=df_starbucks['시군구명'].nunique(), color='red', linestyle='--')
axes[1].text(x=0.5, y=df_starbucks['근방지하철역거리'].mean()+1, s=f'평균: {df_starbucks["근방지하철역거리"].mean():.2f}', ha='left', va='bottom', color='red')
axes[1].set_xticks(gu_cnt)
axes[1].set_xticklabels(gu_cnt, rotation=90)


sns.boxplot(data=df_starbucks, x='시군구명', y='평당거래금액(만원)', ax=axes[2], color='green')
axes[2].hlines(y=df_starbucks['평당거래금액(만원)'].mean(), xmin=0, xmax=df_starbucks['시군구명'].nunique(), color='red', linestyle='--')
axes[2].text(x=0.5, y=df_starbucks['평당거래금액(만원)'].mean()+1, s=f'평균: {df_starbucks["평당거래금액(만원)"].mean():.2f}', ha='left', va='bottom', color='red')
axes[2].set_xticks(gu_cnt)
axes[2].set_xticklabels(gu_cnt, rotation=90)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 7))
plt.xticks(rotation=90)
sns.boxplot(data=df_starbucks, y='평당거래금액(만원)', color='green')
# Out:
# <Axes: ylabel='평당거래금액(만원)'>

# %%
cd /Users/jade/Desktop/prj/MARKET_ANALYSIS/git
# Out:
# /Users/jade/Desktop/prj/market_analysis/git

# %%
# 스타벅스 위치 
# c: 평당 거래금액(만원)
# s: 인근 가게 수
# current_path = 'Users/jade/Desktop/prj/상권분석/git/market_area_analysis/'
shp_file_path = 'market_area_analysis/shp_files/LARD_ADM_SECT_SGG_11_202502.shp'
# full_path = os.path.join(current_path, shp_file_path)


seoul_boundary = gpd.read_file(shp_file_path) #gpd로 읽고
seoul_boundary = seoul_boundary.to_crs(epsg=4326) #tocrs를 통해 4326으로 변환

fig, ax = plt.subplots(figsize=(10, 7))
seoul_boundary.plot(ax=ax, edgecolor="black", facecolor="none")

plt.scatter(x=df_starbucks['경도'], 
            y=df_starbucks['위도'], 
            s=10, c='green')

plt.xlabel('경도')
plt.ylabel('위도')
plt.title('스타벅스 분포')
# plt.colorbar(label='평당거래금액(만원)')


# ctx.add_basemap(ax=ax,
#                 crs=seoul_boundary.crs, 
#                 source=ctx.providers.OpenStreetMap.Mapnik)

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df_starbucks, x='시군구명', y='근방지하철역거리', color='green')
plt.hlines(df_starbucks['근방지하철역거리'].mean(), xmin=0, xmax=df_starbucks['시군구명'].nunique(), colors='red', linestyles='--')
plt.text(x=0.5, y=df_starbucks['근방지하철역거리'].mean() + 0.3,  s=f'평균: {df_starbucks['근방지하철역거리'].mean():.2f}', color='red')

plt.hlines(df_starbucks['근방지하철역거리'].median(), xmin=0, xmax=df_starbucks['시군구명'].nunique(), colors='blue', linestyles='-')
plt.text(x=0.5, y=df_starbucks['근방지하철역거리'].median() + 0.3,  s=f'중앙값: {df_starbucks['근방지하철역거리'].median():.2f}', ha='right' , color='blue')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df_starbucks, x='시군구명', y='상권중심점거리', color='green')
plt.hlines(df_starbucks['상권중심점거리'].mean(), xmin=0, xmax=df_starbucks['시군구명'].nunique(), colors='red', linestyles='--')
plt.text(x=0.5, y=df_starbucks['상권중심점거리'].mean() + 0.3,  s=f'평균: {df_starbucks['상권중심점거리'].mean():.2f}', color='red')

plt.hlines(df_starbucks['상권중심점거리'].median(), xmin=0, xmax=df_starbucks['시군구명'].nunique(), colors='blue', linestyles='-')
plt.text(x=0.5, y=df_starbucks['상권중심점거리'].median() + 0.3,  s=f'중앙값: {df_starbucks['상권중심점거리'].median():.2f}', ha='right' , color='blue')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df_starbucks, x='시군구명', y='평당거래금액(만원)', color='green')
plt.hlines(df_starbucks['평당거래금액(만원)'].mean(), xmin=0, xmax=df_starbucks['시군구명'].nunique(), colors='red', linestyles='--')
plt.text(x=0.5, y=df_starbucks['평당거래금액(만원)'].mean() + 0.3,  s=f'평균: {df_starbucks['평당거래금액(만원)'].mean():.2f}', color='red')

plt.hlines(df_starbucks['평당거래금액(만원)'].median(), xmin=0, xmax=df_starbucks['시군구명'].nunique(), colors='blue', linestyles='-')
plt.text(x=0.5, y=df_starbucks['평당거래금액(만원)'].median() + 0.3,  s=f'중앙값: {df_starbucks['평당거래금액(만원)'].median():.2f}', ha='right' , color='blue')
plt.xticks(rotation=90)
plt.show()

# %%
df_starbucks.to_csv('df_starbucks.csv', encoding='utf-8-sig', index=False)

# %%
df_starbucks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 641 entries, 518203 to 518843
# Data columns (total 35 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   상호명         641 non-null    object
#  1   상권업종대분류명    641 non-null    object
#  2   상권업종중분류명    641 non-null    object
#  3   상권업종소분류명    641 non-null    object
#  4   시군구명        641 non-null    object
#  5   행정동코드       641 non-null    int64
#  6   행정동명        641 non-null    object
#  7   지번주소        641 non-null    object
#  8   도로명주소       641 non-null    object
#  9   경도          641 non-null    float64
#  10  위도          641 non-null    float64
#  11  스타벅스        641 non-null    int64
#  12  근방가게수       641 non-null    int64
#  13  근방음식점수      641 non-null    int64
#  14  근방카페수       641 non-null    int64
#  15  근방지하철역      641 non-null    object
#  16  근방지하철역거리    641 non-null    float64
#  17  승차이용객수      641 non-null    float64
#  18  승차출근시간대     641 non-null    float64
#  19  승차퇴근시간대     641 non-null    float64
#  20  하차이용객수      641 non-null    float64
#  21  하차출근시간대     641 non-null    float64
#  22  하차퇴근시간대     641 non-null    float64
#  23  계           641 non-null    int64
#  24  0세6세        641 non-null    int64
#  25  7세19세       641 non-null    int64
#  26  20세25세      641 non-null    int64
#  27  26세30세      641 non-null    int64
#  28  31세40세      641 non-null    int64
#  29  41세50세      641 non-null    int64
#  30  51세60세      641 non-null    int64
#  31  61세109세     641 non-null    int64
#  32  평당거래금액(만원)  641 non-null    float64
#  33  상권중심점       641 non-null    int64
#  34  상권중심점거리     641 non-null    float64
# dtypes: float64(11), int64(15), object(9)
# memory usage: 180.3+ KB

# %%
df_starbucks.groupby('시군구명')[['승차이용객수','승차출근시간대','승차퇴근시간대','하차이용객수','하차출근시간대','하차퇴근시간대']].agg('mean').style.background_gradient()
# Out:
# <style type="text/css">
# #T_d559a_row0_col0, #T_d559a_row0_col3, #T_d559a_row23_col2, #T_d559a_row23_col5 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_d559a_row0_col1, #T_d559a_row21_col1 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_d559a_row0_col2, #T_d559a_row2_col4 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_d559a_row0_col4 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_d559a_row0_col5 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_d559a_row1_col0 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_d559a_row1_col1 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_d559a_row1_col2, #T_d559a_row9_col5 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_d559a_row1_col3, #T_d559a_row5_col4 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_d559a_row1_col4 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_d559a_row1_col5 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_d559a_row2_col0, #T_d559a_row2_col2, #T_d559a_row2_col3, #T_d559a_row2_col5, #T_d559a_row3_col4, #T_d559a_row11_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_d559a_row2_col1 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_d559a_row3_col0, #T_d559a_row6_col2, #T_d559a_row15_col0 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_d559a_row3_col1, #T_d559a_row10_col3, #T_d559a_row13_col1 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_d559a_row3_col2 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_d559a_row3_col3 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_d559a_row3_col5 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_d559a_row4_col0, #T_d559a_row17_col0 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_d559a_row4_col1, #T_d559a_row21_col0 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_d559a_row4_col2 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# #T_d559a_row4_col3, #T_d559a_row13_col4 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_d559a_row4_col4 {
#   background-color: #056ead;
#   color: #f1f1f1;
# }
# #T_d559a_row4_col5, #T_d559a_row11_col5 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_d559a_row5_col0 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_d559a_row5_col1 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_d559a_row5_col2 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_d559a_row5_col3 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_d559a_row5_col5, #T_d559a_row21_col4 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_d559a_row6_col0 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_d559a_row6_col1 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_d559a_row6_col3, #T_d559a_row20_col1 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_d559a_row6_col4 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_d559a_row6_col5, #T_d559a_row15_col3 {
#   background-color: #4697c4;
#   color: #f1f1f1;
# }
# #T_d559a_row7_col0, #T_d559a_row14_col4, #T_d559a_row16_col4, #T_d559a_row18_col4 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_d559a_row7_col1 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_d559a_row7_col2, #T_d559a_row23_col4 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_d559a_row7_col3 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_d559a_row7_col4 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_d559a_row7_col5 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_d559a_row8_col0, #T_d559a_row8_col3, #T_d559a_row8_col5, #T_d559a_row11_col2, #T_d559a_row11_col4, #T_d559a_row24_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_d559a_row8_col1 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_d559a_row8_col2 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_d559a_row8_col4, #T_d559a_row21_col3 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_d559a_row9_col0 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_d559a_row9_col1, #T_d559a_row16_col1 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_d559a_row9_col2 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_d559a_row9_col3 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_d559a_row9_col4 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_d559a_row10_col0 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_d559a_row10_col1 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_d559a_row10_col2 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_d559a_row10_col4, #T_d559a_row17_col3 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_d559a_row10_col5 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_d559a_row11_col0 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_d559a_row11_col3 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_d559a_row12_col0 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_d559a_row12_col1 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_d559a_row12_col2, #T_d559a_row14_col1 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_d559a_row12_col3, #T_d559a_row16_col3 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_d559a_row12_col4 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_d559a_row12_col5 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_d559a_row13_col0, #T_d559a_row13_col3 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_d559a_row13_col2 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_d559a_row13_col5 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_d559a_row14_col0, #T_d559a_row14_col3 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_d559a_row14_col2, #T_d559a_row14_col5, #T_d559a_row22_col4 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_d559a_row15_col1 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_d559a_row15_col2 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_d559a_row15_col4, #T_d559a_row19_col1 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_d559a_row15_col5, #T_d559a_row24_col0 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_d559a_row16_col0 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_d559a_row16_col2, #T_d559a_row18_col1, #T_d559a_row23_col0 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_d559a_row16_col5 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_d559a_row17_col1 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_d559a_row17_col2, #T_d559a_row17_col4 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_d559a_row17_col5 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_d559a_row18_col0, #T_d559a_row18_col3, #T_d559a_row22_col5 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_d559a_row18_col2, #T_d559a_row21_col5 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_d559a_row18_col5 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_d559a_row19_col0 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_d559a_row19_col2 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_d559a_row19_col3 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_d559a_row19_col4 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_d559a_row19_col5, #T_d559a_row22_col2 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_d559a_row20_col0, #T_d559a_row20_col3 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_d559a_row20_col2 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_d559a_row20_col4 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_d559a_row20_col5 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_d559a_row21_col2 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_d559a_row22_col0, #T_d559a_row22_col3 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_d559a_row22_col1 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_d559a_row23_col1 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_d559a_row23_col3 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_d559a_row24_col2 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_d559a_row24_col3 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_d559a_row24_col4 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_d559a_row24_col5 {
#   background-color: #3991c1;
#   colo

# %%
# 스타벅스 위치 
# c: 평당 거래금액(만원)
# s: 인근 가게 수
# current_path = 'Users/jade/Desktop/prj/상권분석/git/market_area_analysis/'
shp_file_path = 'market_area_analysis/shp_files/LARD_ADM_SECT_SGG_11_202502.shp'
# full_path = os.path.join(current_path, shp_file_path)


seoul_boundary = gpd.read_file(shp_file_path) #gpd로 읽고
seoul_boundary = seoul_boundary.to_crs(epsg=4326) #tocrs를 통해 4326으로 변환

fig, ax = plt.subplots(figsize=(10, 7))
seoul_boundary.plot(ax=ax, edgecolor="black", facecolor="none")

plt.scatter(x=df_starbucks['경도'], 
            y=df_starbucks['위도'], 
            s=df_starbucks['승차출근시간대']/100,
            c=df_starbucks['하차출근시간대'],
            cmap='viridis',
            alpha=0.7)
plt.colorbar(label='하차 출근시간대')
plt.title('지하철역별 출근시간 승차/하차 패턴')

# ctx.add_basemap(ax=ax,
#                 crs=seoul_boundary.crs, 
#                 source=ctx.providers.OpenStreetMap.Mapnik)

plt.show()

# %%
# 스타벅스 위치 
# c: 평당 거래금액(만원)
# s: 인근 가게 수
# current_path = 'Users/jade/Desktop/prj/상권분석/git/market_area_analysis/'
shp_file_path = 'market_area_analysis/shp_files/LARD_ADM_SECT_SGG_11_202502.shp'
# full_path = os.path.join(current_path, shp_file_path)


seoul_boundary = gpd.read_file(shp_file_path) #gpd로 읽고
seoul_boundary = seoul_boundary.to_crs(epsg=4326) #tocrs를 통해 4326으로 변환

fig, ax = plt.subplots(figsize=(10, 7))
seoul_boundary.plot(ax=ax, edgecolor="black", facecolor="none")

plt.scatter(x=df_starbucks['경도'], 
            y=df_starbucks['위도'], 
            s=df_starbucks['승차퇴근시간대']/100,
            c=df_starbucks['하차퇴근시간대'],
            cmap='viridis',
            alpha=0.7)
plt.colorbar(label='하차 출근시간대')
plt.title('지하철역별 출근시간 승차/하차 패턴')

# ctx.add_basemap(ax=ax,
#                 crs=seoul_boundary.crs, 
#                 source=ctx.providers.OpenStreetMap.Mapnik)

plt.show()
